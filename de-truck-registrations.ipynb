# %% [markdown]
# # German Truck Registration Graph in Colab
#
# This notebook sets up the environment and runs the graph generation script directly from the GitHub repository.

# %% [markdown]
# ### Run the Project
#
# The single cell below handles everything:
# 1. It cleans up any previous runs.
# 2. It clones the GitHub repository to get the script and data file.
# 3. It installs the necessary Python packages.
# 4. It runs the script to generate and display the graph.
#
# Just click the "Play" button on the cell to see the result.

# %%
# Clean up any previous clone to ensure a fresh start
# %cd /content
# !rm -rf de-truck-registrations

# Clone the repository
# !git clone https://github.com/eik3/de-truck-registrations.git

# Change into the repository's directory
# %cd de-truck-registrations

# Install the required Python packages
# !pip install -r requirements.txt

# Run the script to generate and display the graph
# We use exec(open(...).read()) instead of %run. This executes the script's
# code directly in the cell's context, which correctly engages Colab's
# display hooks for matplotlib to show the plot inline.
exec(open('graph.py').read())
